# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import re
import time

driver=webdriver.Chrome()

url='https://www.starbucks.co.kr/store/store_map.do?disp=locale'

driver.get(url)
time.sleep(5)
select_btn='#container > div > form > fieldset > div > section > article.find_store_cont > article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(1) > a'

driver.find_element('css selector', select_btn).click()
time.sleep(5)
s_all_btn = '#mCSB_2_container > ul > li:nth-child(1) > a'

driver.find_element('css selector',s_all_btn).click()
time.sleep(5)
html=driver.page_source

soup=BeautifulSoup(html,'html.parser')

starbucks_list=soup.select("#mCSB_3_container > ul > li")

starbucks_list_con=soup.select("li.quickResultLstCon")

starbucks_list[0]

starbucks_addr=[]
for item in starbucks_list:
    addr=str(item.select("p")[0]).split("<br/>")[0].split(">")[1]
    starbucks_addr.append(addr)
starbucks_addr

count=0
gu_lst=[]
for addr in starbucks_addr:  # 주소에서 구만 뽑음.
    gu=addr.split(' ')[1]
    gu_lst.append(gu)

gu_lst_set=sorted(list(set(gu_lst)))  # 구의 종류
print(gu_lst_set)

res=[]
for gu in gu_lst:
    for name in gu_lst_set:
        if name in gu:
            s=name+'-'+str(gu_lst.count(name))
            res.append(s)
res=sorted(list(set(res)))   # ex 강남구-91, 강동구-17.... 로 출력
print(res)

max=0
for r in res:
    if max < int(r.split('-')[1]):
        max=int(r.split('-')[1])
        max_gu=r.split('-')[0]

print('스타벅스 매장이 가장 많은 구는 {}이고 {}개가 있다.'.format(max_gu,max))
        

min=max
for r in res:
    if min > int(r.split('-')[1]):
        min=int(r.split('-')[1])
        min_gu=r.split('-')[0]

print('스타벅스 매장이 가장 적은 구는 {}이고 {}개가 있다.'.format(min_gu,min))

hap=0
for r in res:
    hap+=int(r.split('-')[1])
avg_starbucks=hap/len(gu_lst_set)
print('서울에 있는 구에는 평균 {}개의 스타벅스 매장이 있다.'.format(avg_starbucks))
# Out:
# ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']
# ['강남구-91', '강동구-17', '강북구-6', '강서구-27', '관악구-12', '광진구-19', '구로구-14', '금천구-13', '노원구-14', '도봉구-7', '동대문구-13', '동작구-11', '마포구-36', '서대문구-22', '서초구-48', '성동구-14', '성북구-15', '송파구-36', '양천구-17', '영등포구-41', '용산구-24', '은평구-14', '종로구-40', '중구-54', '중랑구-8']
# 스타벅스 매장이 가장 많은 구는 강남구이고 91개가 있다.
# 스타벅스 매장이 가장 적은 구는 강북구이고 6개가 있다.
# 서울에 있는 구에는 평균 24.52개의 스타벅스 매장이 있다.

# %%
import time
# 인스타그램에서
# 1) '울릉도맛집'을 검색해서 나온 결과물을 스크래핑하여 텍스트만 추출
# 2) 게시글 10개 스크래핑하고, 각게시글 추출
# 3) 댓글도 스크래핑
driver=webdriver.Chrome()

driver.get('https://www.instagram.com/') # 인스타그램 접속
time.sleep(2)

input_id=driver.find_element('css selector','#loginForm > div > div:nth-child(1) > div > label > input')

input_pw=driver.find_element('css selector','#loginForm > div > div:nth-child(2) > div > label > input')

input_id.send_keys('chuchuchu_choo')

input_pw.send_keys('passwd')

input_pw.submit()  # pw입력후 엔터 키 입력과 동일
time.sleep(3)

driver.get('https://www.instagram.com/explore/tags/%EC%9A%B8%EB%A6%89%EB%8F%84%EB%A7%9B%EC%A7%91/')
time.sleep(6)

driver.page_source

driver.find_element('css selector', 'div._aagw').click()
time.sleep(3)

html=driver.page_source
soup=BeautifulSoup(html,'html.parser')
soup

title_lst=[]
title = soup.select('div._a9zr h1')
title[0].text
title_lst.append(title[0].text)
title_lst

next_btn=driver.find_element('css selector','body > div.x1n2onr6.xzkaem6 > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div:nth-child(1) > div > div > div > button')
# next_btn.click()

for i in range(9):
    next_btn.click()
    time.sleep(3)
    html=driver.page_source
    soup=BeautifulSoup(html,'html.parser')
    title = soup.select('div._a9zr h1')
    title_lst.append(title[0].text)
print(title_lst)
# Out:
# ['[#캄인블루프리다이빙] 제목 : 울릉도캠프 오세요~✨  캄인블루 울릉도캠프 모집 시작‼️ 캠프당 최대 인원 10명입니다 6월 캠프 6/6(목) ~ 6/10(월) 8월 캠프 8/7(수) ~ 8/11(일) 9월 캠프 9/5(목) ~ 9/9(월) ▫️참여 조건 : 프리다이빙 자격증 소유한 다이버 누구나 ▫️캠프비 : 85만원 (배값 제외하고 숙박/식비/다이빙비/보팅비 포함) ▫️참여신청 : 카톡 junsh0724 or 인스타 DM - 끝 -저희 ‘캄인블루’ 는 서울/울릉도 모두 프리다이빙 교육이 가능합니다‼️ *울릉도 센터는 5월~10월까지 운영합니다#전성호강사#캄인블루▫️ᗪIᐯEᖇ @s_dong9999 @han__ii6 ▫️ᑭᕼOTO @jjungoo.world', '울릉도에서 먹고 맛있었던 음식들만 올려봅니다.#태양식당 #때개비칼국수 #전호나물 (면발이 너무 쫄깃했고. 전호나물은 미나리과인데 겨울에만 나온다네요)#울릉약소마을 #약소 (한우라 130g 35,000원 최소3인분 이상주문가능합니다. 고기 맛있어요 ~~!!! 된장찌개는×)#대가야 #해물짬뽕 #간짜장 (간짜장 진짜 맛있었습니다)#울릉오징어회타운 #강릉수산 (사진은 6만원어치입니다)#정애식당 #꽁치물회 (개인적으로는 안비리고 고소했네요.꽁치는 등푸른생선이라 냉동시켜서 사용해야 탈이 안난다고 합니다)그외에도 포항에서 배타기 전에 먹었던 #영일대 #마라도회식당 #물회 맛있었고울릉도 #때개비죽 맛났습니다.#울릉도맛집', '내년 여름 울릉도 여행에 참고하시라고 만든 #울릉도맛집 모음Zip.🤤🔖 ‘신비섬횟집’ 물회 물회좀 먹어본 여자의 인생 물회 집..🥹 4박 5일 동안 두번 먹었대요. 먹는 방법이 특이해요. 비빔회로 한번, 물회로 두번 죠져 주는데 너무너무 맛있습니다!!! 🔖 ’현포교동반점‘ 중화 비빔밥, 탕수육 울릉도까지 와서 무슨 중식이냐😤 하시겠지만, 다이빙 끝나고 뜨끈한 온돌 방에서 먹는 중화비빔밥과 산더미 탕수육 정말 최고!!!! 짜장 짬뽕도 맛있었지만 중화비빔밥 진짜 불맛 최고😋🔖 ‘저동오징어회타운’ 강릉수산 울릉도에서 오징어🦑 수율이 급감해서.. 오징어 회는 다른 회와 같이 구매해야만 먹을수가 있는데요, 강릉 수산 정말 잘 챙겨주시고 횟감 상태들이 너무 싱싱 했어요. 마지막 사진은...헿.. #울릉도프리다이빙 해본 사람들은 다 알 사진🐚ㅋㅋ✅Tip. 울릉도 식당들은 네이버 지도에 나와있는 영업시간들과 다르게 운영될 수 있으니 전화 후 방문 필수📞‼️..#울릉도#프리다이빙#프리다이빙투어#프리다이버#커플취미#부부취미#부부여행#국내여행#울릉도캠핑#촌캉스#해루질#바다수영', '울릉도에서 먹은음식 중 젤 맛있었던 곳울릉도 여행 중 사막의 오아시스 같았던 곳다 만족스럽지 못했던 울릉도 음식점들 중 제일 맛있게 먹었음ㅋㅋ ⠀울릉도가 오징어로 유명하니 시켜본 오삼불고기 꿀맛이었고 확실히 냉동오징어가 아니라 야들야들함첨 먹어보는 따개비칼국수도 짱맛😍 따개비 첨 먹어봤는데 맛있더라공ㅋ국물 얼큰~~하이 부산오기전에 한그릇 더 먹고싶었는데 그노메 패키지 일정땜에 먹을날이 음슴..^^⠀울릉도 패키지는 진짜 비추입니더ㅋㅋ한번쯤 가더라도 꼭 자유로가세여...ㅎ⠀⠀⠀⠀#우성식당#따개비칼국수#따개비칼국수맛집#오삼불고기#오삼불고기맛집#울릉도우성식당#울릉도맛집#울릉도맛집추천#울릉도밥집#울릉도핫플#울릉도여행#울릉도여행코스#윤쏘울릉도', "디엠으로 문의 많이 주셨던, 울릉도 독도여행 꿀팁&맛집 풉니다! (혹시 추가 궁금하신점 있으시면 댓글 달아주세요! 답변 드릴게요)📍교통편 *'가보고 싶은 섬' 사이트에서 배편 예약할 수 있음 *만 34세 이하라면 바다로티켓(1년/7,900원)끊어서 국내선박 주중 50% 주말 30% 할인 받을 수 있음*만 34세 이상이라면 보통 울릉도 출발은 강릉 묵호항이나 포항에서 출발하는데, 포항 출발의 경우 ktx 비용 50% 할인 받아 조금 싸게 이동할 수 있음포항-울릉도(왕복) 137,000원 👉소요시간 3:30(파도가 셀 경우, 시간은 길어질 수 있어요)울릉도-독도(왕복) 51,000원 👉소요시간 3:00독도접안 정보👉날씨가 아무리 좋아도 독도 선착장 파도 높이에 따라 접안여부가 결정됩니다. 접안 못할 시 독도 주변을 돌며 선회유람 해주십니다. 저는 정말 감사하게도 독도 땅 밟고 왔네요!📍음식편디엠으로 추천해준 푸글렛들 감사해요!ㅎㅎ<저동>-천금수산(독도새우)-정애분식(홍따밥/홍합따개비밥/꽁치물회) 오징어내장탕도 같이주는데 시원하고 맛있어요!-저동숯불막창 -저동항 제일약국 옆 오징어 회떠주는 집이 있는데 거기서 회떠서 바다보며 먹으면 좋아요! 1마리에 1만원! - 카페는 저동커피나 글림 추천!<도동>-다애식당(따개비밥)-보성식육식당(칡소,약소)-다와호떡(호박식혜와 호떡)-이사부초밥<사동>-심비섬물회<천부>-나리분지야영장식당 -신애분식(따개비칼국수)-만광식당-일호식당-카페울라(저는 못가봤지만, 뷰가 진짜 최고라고 하더라구요)그리고 혹시 차를 가지고 가신다면, 태하쪽 늘푸르니에서 건어물 사시면 좋아요! 📍숙소편-저는 뚜벅이라 저동항에서 거의 숙소를 잡았는데요! 사실 너무 비싸요ㅜ 차가 있으시거나 택시로 이동할 분이라면 천부쪽에 숙소를 잡으시는걸 추천드립니다! 시내를 벗어난 지역이다보니 숙소비도 시내대비 저렴하고 뷰도 더 예쁘답니다! 📍볼거리 -관음도-삼선암-저동도동해안산책로(여긴 태풍의 영향으로 현재 일부구간만 통행할 수 있다고 해요)-촛대바위(저는 이곳에서 일출을 봤어요!)-나리분지 -성인봉(원시림)-봉래폭포-독도일출전망대 케이블카📍그 외 팁! -울릉도는 버스 배차간격이 거의 1시간마다 있어서 항상 버스시간표를 보면서 이동해야 해요! 저처럼 혼자 여행하시거나, 차없이 이동하는 경우 네이버에 울릉도 버스시간표 치시면 나오니 참고하시면 됩니다!-택시는 비싸다고 해서 거의 걸어다녔는데, 거의 10분거리 이동시 14,000원정도 든다고 하네요!#푸글_울릉도 #울릉도맛집 #울릉도여행 #독도여행 #독도 #울릉도", '🏞️해안산책로🏞️가 예술인 산책명소!!!.국내에서 가장 아름다운 바다색을 만날 수 있는 곳, 가을 여행으로 핫한 울릉도, 재방문을 하려고 하니,, 객실이 없는 거 실화?? 행남해안산책로는 울릉도 필수 사진 스팟, 그리고 트레킹의 성지로 떠오르는 곳, 울릉도 가을 여행 너무 핫한거 아니야?🥰💕..📍행남해안산책로..#울릉도 #울릉도여행 #행남해안산책로 #울릉도가볼만한곳 #해안도로 #해안산책로 #트레킹 #울릉도카페 #가을여행 #여행스타그램 #사진스타그램 #울릉크루즈 #울릉도맛집 #울릉도프리다이빙 #카페울라 #코스모스리조트', '#경주여행코스 #제주개인스냅 #동성로네일 #분당메이크업 #합판가구 #울릉도맛집 #대구속눈썹잘하는곳 #김포필라테스 #답례품캔들 #레터링케이크창업반 #다사눈썹문신 #백일답례떡 #곤지암꽃집 #육아동지 #남자타투추천', '📍울릉도✅ #마루통닭/ 마늘통닭 하트점수 : ♥️♥️♥️♥️♥️♥️♥️⠀< 백숙파, 통닭파를 모두 만족시킬 하이브리드 통닭집 > 우리나라 분들은 치킨의 민족이라고 해도 될 정도로 닭 요리를 좋아하시죠. 저도 그 사람 중의 한 명인만큼 맛있는 치킨, 통닭집이라면 꼭 먹어보는 편입니다. 울릉도에서 no.1 통닭집이라면 얼마나 맛있는지 궁금해지잖아요.#마루통닭 은 백숙과 통닭의 맛을 동시에 느낄 수 있는 하이브리드 통닭입니다. 첫 등장은 바삭한 옛날통닭위에 푸짐한 마늘 소스가 올라가 있는 형태입니다. 마늘이 듬뿍 올라가면 한국인이라면 무조건 좋아할 맛이죠. 사장님이 해체해주시고 나면 백숙처럼 촉촉한 살코기로 변해 백숙파와 통닭파를 모두 만족시킬 수 있습니다. 통닭을 아주 얇게 찢어 마늘 소스에 버무려 먹으면 몸보신하는 느낌까지 받을 수 있습니다. 마루통닭은 그날 그날 사용할만큼만의 재료를 준비하시기 때문에 늦게 가시면 드실 수 없습니다. 껍질도 얇고 바삭해 옛날통닭 좋아하신다면 꼭 드셔보시길 추천해드립니다. 치킨의 짝꿍인 치킨무도 맛있고 생맥주와 함께면 여행의 마무리로 완벽합니다. 내부 테이블은 협소한 편이고, 나오는데 시간이 걸리는 편이라 포장 주문 혹은 웨이팅 시간을 생각하시고 방문하시는게 좋겠습니다. ◾ #마루통닭 ◾ 경북 울릉군 울릉읍 도동길 95◾ 매일 11:30 - 재료 소진 시 ◾ 주차 불가 ◽◾ 마늘통닭 20,000원# ...
